# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("F:\Techie_MUS\DataScience\Git_Workspace\Coursera_Capstone\Geospatial_Coordinates.csv")
op_df = pd.read_csv("F:\Techie_MUS\DataScience\Git_Workspace\Coursera_Capstone\Postal_Values.csv")

# %%
op_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
op_df['Postal Code'] = op_df['Postal Code'].astype('str')
op_df.sort_values(by=['Postal Code'], ascending=True, inplace=True)
op_df.reset_index(drop=True, inplace=True)
op_df
# Out:
#     Postal Code       Borough  \
# 0          M1B   Scarborough
# 1          M1C   Scarborough
# 2          M1E   Scarborough
# 3          M1G   Scarborough
# 4          M1H   Scarborough
# ..          ...           ...
# 98         M9N          York
# 99         M9P     Etobicoke
# 100        M9R     Etobicoke
# 101        M9V     Etobicoke
# 102        M9W     Etobicoke
#
#                                          Neighbourhood
# 0                                      Malvern, Rouge
# 1              Rouge Hill, Port Union, Highland Creek
# 2                   Guildwood, Morningside, West Hill
# 3                                              Woburn
# 4                                           Cedarbrae
# ..                                                 ...
# 98                                             Weston
# 99                                          Westmount
# 100  Kingsview Village, St. Phillips, Martin Grove ...
# 101  South Steeles, Silverstone, Humbergate, Jamest...
# ...

# %%
df['Postal Code'] = df['Postal Code'].astype('str')
df.sort_values(by=['Postal Code'], ascending=True, inplace=True)
df
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
#mergedDf = df2.merge(df1, left_index=True, right_index=True)
#mergedDf
df_row = pd.concat([op_df, df], axis=1)
df_row = df_row.loc[:,~df_row.columns.duplicated()]
df_row
# Out:
#     Postal Code       Borough  \
# 0          M1B   Scarborough
# 1          M1C   Scarborough
# 2          M1E   Scarborough
# 3          M1G   Scarborough
# 4          M1H   Scarborough
# ..          ...           ...
# 98         M9N          York
# 99         M9P     Etobicoke
# 100        M9R     Etobicoke
# 101        M9V     Etobicoke
# 102        M9W     Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                      Malvern, Rouge   43.806686 -79.194353
# 1              Rouge Hill, Port Union, Highland Creek   43.784535 -79.160497
# 2                   Guildwood, Morningside, West Hill   43.763573 -79.188711
# 3                                              Woburn   43.770992 -79.216917
# 4                                           Cedarbrae   43.773136 -79.239476
# ..                                                 ...        ...        ...
# ...

# %%
#op_df['Postal Code'] = op_df['Postal Code'].astype('str')

# %%
#df['Postal Code'] = df['Postal Code'].astype('str')

# %%
#merged = pd.merge(left=df2, right=df1, left_on='Postal Code', right_on='Postal Code')
#merged.shape

# %%
#merged
